# %% [markdown]
# # Лабораторная работа 4.
# # Методы поиска.

# %% [markdown]
# # Выполнил студент группы БСТ2103 Бидная М.В.

# %% [markdown]
# # Задание.
# # Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.

# %% [markdown]
# # Задание 1.

# %%
import random
import time
# генерация массива
A = []
n = int(input("Введите кол-во элементов ", ) or "20")
min_limit = int(input("Введите минимальное значение генерируемых чисел: ", ) or "-20")
max_limit = int(input("Введите максимальное значение генерируемых чисел: ", ) or "20")
if min_limit >= max_limit:
    print("Минимальное не может быть больше максимального. Были взяты значения по умолчанию!")
    min_limit = -20
    max_limit = 20
for i in range(n):
    A.append(random.randint(min_limit,max_limit))
A.sort()
print("\nСгенерирован начальный набор случайных данных: ", A)

# линейный поиск
x = int(input("Введите элемент, который хотите найти с помощью функции линейного поиска: ", ))
lin_start_time = time.time()
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return 'В сгенерированном массиве нет элемента с таким значением'

print(linear_search(A,x))
print(f"{(time.time() - lin_start_time)*1000} миллисекунд")
x = int(input("Введите элемент, который хотите вставить: ", ))
# функция вставки элемента
def insert_insert(arr, x):
    arr.append(x)
    arr.sort()
    return arr

print("Вывод сортированного массива со вставленным элементом: ")
print(insert_insert(A, x))

x = int(input("Введите элемент, который хотите удалить: ", ))
# функция удаления элемента
def delete_delete(arr, x):
    arr.remove(x)
    arr.sort()
    return arr

print("Вывод сортированного массива с удаленным элементом: ")
print(delete_delete(A, x))

# бинарный поиск
y = int(input("Введите элемент, который хотите найти с помощью функции бинарного поиска: ", ))
bin_start_time = time.time()
def binary_search_iterativ(arr, desired_y):
    # находим среднее значение массива, обозначим верхнюю и нижнюю границу
    middle = len(arr) // 2
    bottom_line = 0
    upper_line = len(arr) - 1
    # сравниваем искомое значение с серединой
    while arr[middle] != desired_y and bottom_line <= upper_line:
        if desired_y > arr[middle]:
            bottom_line = middle + 1
        else:
            upper_line = middle - 1
        # вычесляем индекс новой середины после сдвига одной из границ
        middle = (bottom_line + upper_line) // 2
    # проверка условия, если границы пересеклись
    if bottom_line > upper_line:
        return 'В сгенерированном массиве нет элемента с таким значением'
    else:
        return middle

print(binary_search_iterativ(A, y))
print(f"{(time.time() - bin_start_time)*1000} миллисекунд")
# вставка и удаление в бинарном
a = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод сортированного массива со вставленным элементом: ")
print(insert_insert(A,a))
b = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод сортированного массива с удаленным элементом: ")
print(delete_delete(A,b))

# поиск фибоначчи
z = int(input("Введите элемент, который хотите найти с помощью функции поиска фибоначчи: ", ))
fib_start_time = time.time()
def fibonacci_search(arr, desired_z):
    # первые два числа и третье выраженное суммой прошлых
    first_number = 0
    second_number = 1
    summary_number = first_number + second_number
    # наименьшее число в последовательности
    while summary_number < len(arr):
        first_number = second_number
        second_number = summary_number
        summary_number = first_number + second_number
    index = -1
    # пока в массиве есть элементы и значением суммы>1 делаем следующее
    while (summary_number > 1):
        # i ищем для того, чтобы понять на сколько вниз нам сдвигаться
        i = min(index+first_number, len(arr)-1)
        if arr[i] < desired_z:
            # перемещаем  наши значения на два шага вниз и индекс становится индексом элемента
            summary_number = second_number
            second_number = first_number
            first_number = summary_number - second_number
            index = i
        elif arr[i] > desired_z:
            # перемещаем наши значения на один шаг вниз
            summary_number = first_number
            second_number = second_number - first_number
            first_number = summary_number - second_number
        else:
            return i
    # проверяем значение
    if second_number and index < len(arr)-1 and arr[index+1] == desired_z:
        return index+1
    return 'В сгенерированном массиве нет элемента с таким значением'

print(fibonacci_search(A,z))
print(f"{(time.time() - fib_start_time)*1000} миллисекунд")
# вставка и удаление в фибоначчи
c = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод сортированного массива со вставленным элементом: ")
print(insert_insert(A,c))
d = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод сортированного массива с удаленным элементом: ")
print(delete_delete(A,d))

# интерполяционный поиск
w = int(input("Введите элемент, который хотите найти с помощью функции интерполяционного поиска: ", ))
int_start_time = time.time()
def interpolation_searsh(arr, desired_w):
    start_index = 0
    last_index = len(arr)-1
    while start_index <= last_index and desired_w >= arr[start_index] and desired_w <= arr[last_index]:
        # вычисление вероятной позиции искомого элемента
        index = start_index + int(((float(last_index-start_index)/(arr[last_index]-arr[start_index]))*(desired_w-arr[start_index])))
        # элемент найден
        if arr[index] == desired_w:
            return index
        # пересчитываем индекс для праваого подмассива
        elif arr[index] < desired_w:
            start_index = index + 1
        # пересчитываем индекс для левого подмассива
        else:
            last_index = index - 1
    return 'В сгенерированном массиве нет элемента с таким значением'

print(interpolation_searsh(A,w))
print(f"{(time.time() - int_start_time)*1000} миллисекунд")
# вставка и удаление в интерполяционном поиске
e = int(input("Введите элемент, который хотите вставить: ", ))
print("Вывод сортированного массива со вставленным элементом: ")
print(insert_insert(A,e))
f = int(input("Введите элемент, который хотите удалить: ", ))
print("Вывод сортированного массива с удаленным элементом: ")
print(delete_delete(A,f))

# поиск через бинарное дерево 
# Здесь происходит создание корневого узла
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Сортировка дерева
def inorder(root):
    if root is not None:
        # Обход левого поддерева
        inorder(root.left)
        # Обход корня
        print(str(root.data) + " ", end=' ')
        # Обход правого поддерева
        inorder(root.right)

# Вставка элемента
def insert(node, data):
    # Если дерево пустое, то вернуть новый узел
    if node is None:
        return Node(data)
    # Переход в левое/правое поддерево и вставка узла
    if data < node.data:
        node.left = insert(node.left, data)
    else:
        node.right = insert(node.right, data)
    return node

# Поиск inorder-преемника
def minValueNode(node):
    current = node
    # Inorder-преемник - это найденный крайний левый лист
    while(current.left is not None):
        current = current.left
    return current

# Удаление узла
def deleteNode(root, data):
    # Если дерево пустое, возвращаем
    if root is None:
        return root
    # Необходимо найти узел, который нужно удалить
    if data < root.data:
        root.left = deleteNode(root.left, data)
    elif(data > root.data):
        root.right = deleteNode(root.right, data)
    else:
        # Если у узла только один дочерний узел или вообще их нет
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None
            return temp
        # В случае когда у узла два дочерних узла, помещаем центрированного преемника на место узла, который нужно удалить
        temp = minValueNode(root.right)
        root.data = temp.data
        # Удаляем inorder-преемниа
        root.right = deleteNode(root.right, temp.data)
    return root

root = None
for i in range(len(A)):
    root = insert(root, A[i])

print("\nПоиск через бинарное дерево этого же массива: ", end=' ')
inorder(root)

print("\nВведите элемент, который хотите удалить: ")
del_value = int(input())
root = deleteNode(root, del_value)
print("Вывод сортированный массив с удаленным элементом: ", end=' ')
inorder(root)

print("\nВведите элемент, который хотите вставить: ")
ins_value = int(input())
root = insert(root,ins_value)
print("Вывод сортированный массив со вставленным элементом: ", end=' ')
inorder(root)
# Out:
# Введите кол-во элементов 10
# Введите минимальное значение генерируемых чисел: -20
# Введите максимальное значение генерируемых чисел: 20
#
# Сгенерирован начальный набор случайных данных:  [-17, -16, -9, -9, -5, -4, 0, 5, 13, 20]
# Введите элемент, который хотите найти с помощью функции линейного поиска: -11
# В сгенерированном массиве нет элемента с таким значением
# 1.9948482513427734 миллисекунд
# Введите элемент, который хотите вставить: -11
# Вывод сортированного массива со вставленным элементом:
# [-17, -16, -11, -9, -9, -5, -4, 0, 5, 13, 20]
# Введите элемент, который хотите удалить: 5
# Вывод сортированного массива с удаленным элементом:
# [-17, -16, -11, -9, -9, -5, -4, 0, 13, 20]
# Введите элемент, который хотите найти с помощью функции бинарного поиска: -4
# 6
# 1.0061264038085938 миллисекунд
# Введите элемент, который хотите вставить: 2
# Вывод сортированного массива со вставленным элементом:
# [-17, -16, -11, -9, -9, -5, -4, 0, 2, 13, 20]
# Введите элемент, который хотите удалить: -9
# Вывод сортированного массива с удаленным элементом:
# [-17, -16, -11, -9, -5, -4, 0, 2, 13, 20]
# Введите элемент, который хотите найти с помощью функции поиска фибоначчи: -16
# 1
# 0.0 миллисекунд
# Введите элемент, который хотите вставить: 1
# Вывод сортированного массива со вставленным элементом:
# [-17, -16, -11, -9, -5, -4, 0, 1, 2, 13, 20]
# Введите элемент, который хотите удалить: 13
# Вывод сортированного массива с удаленным элементом:
# [-17, -16, -11, -9, -5, -4, 0, 1, 2, 20]
# Введите элемент, который хотите найти с помощью функции интерполяционного поиска: -11
# 2
# 0.9901523590087891 миллисекунд
# Введите элемент, который хотите вставить: 6
# Вывод сортированного массива со вставленным элементом:
# [-17, -16, -11, -9, -5, -4, 0, 1, 2, 6, 20]
# Введите элемент, который хотите удалить: -5
# Вывод сортированного массива с удаленным элементом:
# [-17, -16, -11, -9, -4, 0, 1, 2, 6, 20]
#
# Поиск через бинарное дерево этого же массива:  -17  -16  -11  -9  -4  0  1  2  6  20
# Введите элемент, который хотите удалить:
# 2
# Вывод сортированный массив с удаленным элементом:  -17  -16  -11  -9  -4  0  1  6  20
# Введите элемент, который хотите вставить:
# 3
# Вывод сортированный массив со вставленным элементом:  -17  -16  -11  -9  -4  0  1  3  6  20

# %% [markdown]
# # Задание 2.

# %% [markdown]
# # Простое рехэширование

# %%
# Создать класс хэш-таблицы
class Hash_Table:
    size = int(input("Введите, пожалуйста, размер хэш-таблицы: "))
    def __init__(self):
        self.data = [None] * self.size
    # Здесь получение содержимого баккета
    def __getitem__(self, key):
        h = self.get_Hash(key)
        try:
            while self.data[h]:
                if self.data[h] and self.data[h].get(key):
                    return self.data[h]
                h = self.get_Rehash(h)
        except IndexError:
            return
    # Здесь заполняется пустой баккет
    def __setitem__(self, key, value):
        h = self.get_Hash(key)
        if self.data[h] is None:
            self.data[h] = {key: value}
            return
        next_h = self.get_Rehash(h)
        try:
            while self.data[next_h] is not None:
                if self.data[next_h].get(key):
                    self.data[next_h].get(key)
                    break
                next_h = self.get_Rehash(next_h)
        except IndexError:
            raise
        self.data[next_h] = {key: value}
    # Сама хэш-функция
    def get_Hash(self, name):
        return len(name) % self.size
    # Это функция рехэширования
    def get_Rehash(self, oldhash):
        return oldhash + 1
# Заполнение хэш-таблицы двумя значениями
table = Hash_Table()
table[input('\nВведите ключ: ')] = input('\nВведите значение: ')
table[input('\nВведите ключ: ')] = input('\nВведите значение: ')
# Вывод одного из значений через ключ
print(table[input('\nВыберите значение по ключу: ')])
# Out:
# Введите, пожалуйста, размер хэш-таблицы: 4
#
# Введите значение: gh
#
# Введите ключ: rt
#
# Введите значение: df
#
# Введите ключ: cv
#
# Выберите значение по ключу: cv
# {'cv': 'df'}

# %% [markdown]
# # Рехеширование с помощью псевдослучайных чисел

# %%
#Рехеширование с помощью псевдослучайных чисел
class randHash:
    def __init__(self):
        self.data = [None]*64   
    def randNumbers(self,i):
        R=[5]
        if len(R) - 1 < i:
            R.append(self.randNumbers(i - 1))
        return (8255 * R[i] + 239) % 64   
    def _hash(self, key,i):
        return (hash(key)+self.randNumbers(i))%(2**4)
    def addItem_Hash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            i+=1
        self.data[self._hash(key,i)] = key
        return self.data   
    def searchHash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            if self.data[self._hash(key,i)] == key:
                return 1
            i+=1
        return 0
    def deleteItem_Hash(self,key):
        i=0
        while self.data[self._hash(key,i)] != None and i<len(self.data):
            if self.data[self._hash(key,i)] == key:
                self.data.pop(self._hash(key,i))
                return self.data
            i+=1
        print("Такого элемента нет")
Digital = randHash()
Digital.addItem_Hash("4")
Digital.addItem_Hash("11")
Digital.addItem_Hash("12")
Digital.searchHash("4")
Digital.deleteItem_Hash("11")
# Out:
# [None,
#  None,
#  None,
#  None,
#  '12',
#  '4',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Метод цепочек

# %%
class ChainMethod:
    def __init__(self):
        self.data = [None]*64
    def _hash(self,key):
        return hash(key)%(2**4)
    def addItem(self, index, key):
        if self.data[index] is None:
            self.data[index] = [key]
            print("элемент был добавлен")
            return 1
        else:
            for i, item in enumerate(self.data[index]):
                if item == key:
                    self.data[index][i] = key
                    print("элемент не был добавлен")
                    return 0
            self.data[index].append(key)
            print("элемент был добавлен")
            return 1
    def searchChain(self,index,item):
        if self.data[index] is not None:
            if self.data[index] == [item]:
                print("Элемент был найден")
                return 1
            else:
                for i, item_ in enumerate(self.data[index]):
                    if self.data[index][i] == item:
                        print("Элемент был найден")
                        return 1
        else:
            print("Элемент не найден")
            return 0
    def deleteItem_Chain(self,index,item):
        if self.data[index] is not None:
            if self.data[index] == [item]:
                self.data[index] = None
                print("Элемент был удален")
                return 1
            else:
                for i, item_ in enumerate(self.data[index]):
                    if self.data[index][i] == item:
                        self.data[index].pop(i)
                        print("Элемент был удален")
                        return 1
        else:
            return 0
tableChain = ChainMethod()
tableChain.addItem(tableChain._hash("Ура"),"Ура")
tableChain.addItem(tableChain._hash("Победа"),"Победа")
tableChain.addItem(tableChain._hash("Завтрак"),"Завтрак")
tableChain.searchChain(tableChain._hash("Завтрак"),"Завтрак")
tableChain.deleteItem_Chain(tableChain._hash("Ура"),"Ура")
# Out:
# элемент был добавлен
# элемент был добавлен
# элемент был добавлен
# Элемент был найден
# Элемент был удален
# 1

# %% [markdown]
# # Задание №3

# %%
board = [[0 for i in range(8)] for j in range(8)]
cnt = 0
cnt2 = 0

def setQueen(i,j):
    global cnt2
    cnt2 += 1
    for x in range(8):
        board[x][j] += 1
        board[i][x] += 1
        if 0 <= i + j - x < 8:
            board[i + j - x][x] += 1
        if 0 <= i - j + x < 8:
            board[i - j + x][x] += 1
    board[i][j] = -1

def removeQueen(i, j):
    for x in range (8):
        board[x][j] -= 1
        board[i][x] -= 1
        if 0 <= i + j - x < 8:
            board[i + j - x][x] -= 1
        if 0 <= i - j + x < 8:
            board[i - j + x][x] -= 1
    board[i][j] = 0

def printPosition():
    global cnt
    cnt += 1
    abc = 'abcdefgh'
    ans = []
    for i in range(8):
        for j in range(8):
            if board[i][j] == -1:
                ans.append(abc[j] + str(i + 1))
    print(', '.join(ans))

def solve(i):
    for j in range(8):
        if board[i][j] == 0:
            setQueen(i, j)
            if i == 7:
                printPosition()
            else:
                solve(i + 1)
            removeQueen (i, j)

solve(0)
print(cnt)
print(cnt2)
# Out:
# a1, e2, h3, f4, c5, g6, b7, d8
# a1, f2, h3, c4, g5, d6, b7, e8
# a1, g2, d3, f4, h5, b6, e7, c8
# a1, g2, e3, h4, b5, d6, f7, c8
# b1, d2, f3, h4, c5, a6, g7, e8
# b1, e2, g3, a4, c5, h6, f7, d8
# b1, e2, g3, d4, a5, h6, f7, c8
# b1, f2, a3, g4, d5, h6, c7, e8
# b1, f2, h3, c4, a5, d6, g7, e8
# b1, g2, c3, f4, h5, e6, a7, d8
# b1, g2, e3, h4, a5, d6, f7, c8
# b1, h2, f3, a4, c5, e6, g7, d8
# c1, a2, g3, e4, h5, b6, d7, f8
# c1, e2, b3, h4, a5, g6, d7, f8
# c1, e2, b3, h4, f5, d6, g7, a8
# c1, e2, g3, a4, d5, b6, h7, f8
# c1, e2, h3, d4, a5, g6, b7, f8
# c1, f2, b3, e4, h5, a6, g7, d8
# c1, f2, b3, g4, a5, d6, h7, e8
# c1, f2, b3, g4, e5, a6, h7, d8
# c1, f2, d3, a4, h5, e6, g7, b8
# c1, f2, d3, b4, h5, e6, g7, a8
# c1, f2, h3, a4, d5, g6, e7, b8
# c1, f2, h3, a4, e5, g6, b7, d8
# c1, f2, h3, b4, d5, a6, g7, e8
# c1, g2, b3, h4, e5, a6, d7, f8
# c1, g2, b3, h4, f5, d6, a7, e8
# c1, h2, d3, g4, a5, f6, b7, e8
# d1, a2, e3, h4, b5, g6, c7, f8
# d1, a2, e3, h4, f5, c6, g7, b8
# d1, b2, e3, h4, f5, a6, c7, g8
# d1, b2, g3, c4, f5, h6, a7, e8
# d1, b2, g3, c4, f5, h6, e7, a8
# d1, b2, g3, e4, a5, h6, f7, c8
# d1, b2, h3, e4, g5, a6, c7, f8
# d1, b2, h3, f4, a5, c6, e7, g8
# d1, f2, a3, e4, b5, h6, c7, g8
# d1, f2, h3, b4, g5, a6, c7, e8
# d1, f2, h3, c4, a5, g6, e7, b8
# d1, g2, a3, h4, e5, b6, f7, c8
# d1, g2, c3, h4, b5, e6, a7, f8
# d1, g2, e3, b4, f5, a6, c7, h8
# d1, g2, e3, c4, a5, f6, h7, b8
# d1, h2, a3, c4, f5, b6, g7, e8
# d1, h2, a3, e4, g5, b6, f7, c8
# d1, h2, e3, c4, a5, g6, b7, f8
# e1, a2, d3, f4, h5, b6, g7, c8
# e1, a2, h3, d4, b5, g6, c7, f8
# e1, a2, h3, f4, c5, g6, b7, d8
# e1, b2, d3, f4, h5, c6, a7, g8
# e1, b2, d3, g4, c5, h6, f7, a8
# e1, b2, f3, a4, g5, d6, h7, c8
# e1, b2, h3, a4, d5, g6, c7, f8
# e1, c2, a3, f4, h5, b6, d7, g8
# e1, c2, a3, g4, b5, h6, f7, d8
# e1, c2, h3, d4, g5, a6, f7, b8
# e1, g2, a3, c4, h5, f6, d7, b8
# e1, g2, a3, d4, b5, h6, f7, c8
# e1, g2, b3, d4, h5, a6, c7, f8
# e1, g2, b3, f4, c5, a6, d7, h8
# e1, g2, b3, f4, c5, a6, h7, d8
# e1, g2, d3, a4, c5, h6, f7, b8
# e1, h2, d3, a4, c5, f6, b7, g8
# e1, h2, d3, a4, g5, b6, f7, c8
# f1, a2, e3, b4, h5, c6, g7, d8
# f1, b2, g3, a4, c5, e6, h7, d8
# f1, b2, g3, a4, d5, h6, e7, c8
# f1, c2, a3, g4, e5, h6, b7, d8
# f1, c2, a3, h4, d5, b6, g7, e8
# f1, c2, a3, h4, e5, b6, d7, g8
# f1, c2, e3, g4, a5, d6, b7, h8
# f1, c2, e3, h4, a5, d6, b7, g8
# f1, c2, g3, b4, d5, h6, a7, e8
# f1, c2, g3, b4, h5, e6, a7, d8
# f1, c2, g3, d4, a5, h6, b7, e8
# f1, d2, a3, e4, h5, b6, g7, c8
# f1, d2, b3, h4, e5, g6, a7, c8
# f1, d2, g3, a4, c5, e6, b7, h8
# f1, d2, g3, a4, h5, b6, e7, c8
# f1, h2, b3, d4, a5, g6, e7, c8
# g1, a2, c3, h4, f5, d6, b7, e8
# g1, b2, d3, a4, h5, e6, c7, f8
# g1, b2, f3, c4, a5, d6, h7, e8
# g1, c2, a3, f4, h5, e6, b7, d8
# g1, c2, h3, b4, e5, a6, f7, d8
# g1, d2, b3, e4, h5, a6, c7, f8
# g1, d2, b3, h4, f5, a6, c7, e8
# g1, e2, c3, a4, f5, h6, b7, d8
# h1, b2, d3, a4, g5, e6, c7, f8
# h1, b2, e3, c4, a5, g6, d7, f8
# h1, c2, a3, f4, b5, e6, g7, d8
# h1, d2, a3, c4, f5, b6, g7, e8
# 92
# 2056
